# %%
import requests
from bs4 import BeautifulSoup
import lxml

# %%
url = "https://en.wikipedia.org/wiki/List_of_current_UFC_fighters"

# %%
search="2%2B2"
headers={'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36'}
page = requests.get(url,headers=headers)

# %%
soup = BeautifulSoup(page.text,"lxml")

# %%
table = soup.find(class_="wikitable")

# %%
tbody = table.find("tbody")

# %%
#tbody

# %%
data = {
    
    "date": [],
    "name": [],
    "nickname": [],
    "division": [],
    "endeavor_record": [],
    "mma_record": []
}

# %%
date = tbody.find("td").find("span").text

# %%
date
# Out:
# 'Aug 8, 2020'

# %%
name = tbody.find_all("td")[2].find("a")["title"]

# %%
name
# Out:
# 'Corey Anderson (fighter)'

# %%
name
# Out:
# 'Corey Anderson (fighter)'

# %%
for i in tbody:
    nickname = i.find_all("td")[3].find("i").text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-660-a4530a03c4c5> in <module>
#       1 for i in tbody:
# ----> 2     nickname = i.find_all("td")[3].find("i").text
#
# IndexError: list index out of range

# %%
for i in tbody:
    print(i.find("td")[2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-661-7fdc611d969d> in <module>
#       1 for i in tbody:
# ----> 2     print(i.find("td")[2])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
nickname
# Out:
# 'Overtime'

# %%
division = tbody.find_all("td")[5].text

# %%
division.strip()
# Out:
# 'Light Heavyweight'

# %%
endeavor_record = tbody.find_all("td")[7].text

# %%
endeavor_record.split()
# Out:
# ['10–5']

# %%
mma_record = tbody.find_all("td")[8].text
mma_record
# Out:
# '13–5\n'

# %%
mma_record.split()
# Out:
# ['13–5']

# %%
tbody = table.find("tbody")

# %%
for list_item in tbody:
    print(list_item.n)
# Out:
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-670-3386460840e6> in <module>
#       1 for list_item in tbody:
# ----> 2     print(list_item.n)
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, attr)
#     916             raise AttributeError(
#     917                 "'%s' object has no attribute '%s'" % (
# --> 918                     self.__class__.__name__, attr))
#     919
#     920     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'n'

# %%
date = tbody.find("td").find("span")

# %%
date
# Out:
# <span data-sort-value="000000002020-08-08-0000" style="white-space:nowrap">Aug 8, 2020</span>

# %%
print(tbody.fetchNextSiblings)
# Out:
# <bound method PageElement.find_next_siblings of <tbody><tr>
# <th width="10%">Date
# </th>
# <th width="3%"><span style="font-size:85%;"><a href="/wiki/ISO_3166-1_alpha-3" title="ISO 3166-1 alpha-3">ISO</a></span>
# </th>
# <th width="14%">Name
# </th>
# <th width="14%">Nickname
# </th>
# <th width="15%">Reason
# </th>
# <th width="17%">Division
# </th>
# <th width="3%">Ref
# </th>
# <th width="11%">Endeavor record
# </th>
# <th width="11%">MMA record
# </th></tr>
# <tr>
# <td><span data-sort-value="000000002020-08-08-0000" style="white-space:nowrap">Aug 8, 2020</span>
# </td>
# ...

# %%
for i in tbody:
    name = tbody.find_all("td")[2].find("a")["title"]
    print(name)
# Out:
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)
# Corey Anderson (fighter)

# %%
date = tbody.find("td").find("span").text
date
tbody.find
# Out:
# <bound method Tag.find of <tbody><tr>
# <th width="10%">Date
# </th>
# <th width="3%"><span style="font-size:85%;"><a href="/wiki/ISO_3166-1_alpha-3" title="ISO 3166-1 alpha-3">ISO</a></span>
# </th>
# <th width="14%">Name
# </th>
# <th width="14%">Nickname
# </th>
# <th width="15%">Reason
# </th>
# <th width="17%">Division
# </th>
# <th width="3%">Ref
# </th>
# <th width="11%">Endeavor record
# </th>
# <th width="11%">MMA record
# </th></tr>
# <tr>
# <td><span data-sort-value="000000002020-08-08-0000" style="white-space:nowrap">Aug 8, 2020</span>
# </td>
# ...

# %%
mma_record = tbody.find_all("td")[8].text
data = {
    
    "date": [],
    "name": [],
    "nickname": [],
    "division": [],
    "endeavor_record": [],
    "mma_record": []
}

# %%
mma_record
# Out:
# '13–5\n'

# %%
date = tbody.find("td").find("span").text
endeavor_record = tbody.find_all("td")[7].text
division = tbody.find_all("td")[5].text
name = tbody.find_all("td")[2].find("a")["title"]
nickname = i.find_all("td")[3].find("i").text
date = tbody.find("td").find("span").text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-678-11e382ef59dc> in <module>
#       3 division = tbody.find_all("td")[5].text
#       4 name = tbody.find_all("td")[2].find("a")["title"]
# ----> 5 nickname = i.find_all("td")[3].find("i").text
#       6 date = tbody.find("td").find("span").text
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, attr)
#     916             raise AttributeError(
#     917                 "'%s' object has no attribute '%s'" % (
# --> 918                     self.__class__.__name__, attr))
#     919
#     920     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'find_all'

# %%
data["mma_record"] = [i.find_all_next("td")[8].text.split() for i in tbody]
data["endeavor_record"] = [i.find_all_next("td")[7].text.split() for i in tbody]
data["division"] = [i.find_all_next("td")[5].text.strip() for i in tbody]
#data["nickname"] = [i.find_all_next("td")[3].text.strip() for i in tbody]
data["nickname"] = [i.find_all_next("td")[3].text.strip() for i in tbody] 
data["name"] = [i.find_all_next("td")[2].text.strip() for i in tbody]
data["date"] = [i.find_all_next("td")[0].text.strip() for i in tbody]

# %%
for i in tbody:
    print(i.find_all_next("td")[2].text.strip())
# Out:
# Corey Anderson
# Corey Anderson
# Corey Anderson
# Ray Borg
# Ray Borg
# Roman Bogatov
# Roman Bogatov
# Tai Tuivasa
# Tai Tuivasa
# Paige VanZant
# Paige VanZant
# Bethe Correia
# Bethe Correia
# Evan Dunham
# Evan Dunham
# Max Rohskopf
# Max Rohskopf
# Daniel Cormier *
# Daniel Cormier *
# Kevin Croom
# Kevin Croom
# Ricardo Lamas *
# Ricardo Lamas *
# Sergio Giglio

# %%
data
# Out:
# {'date': ['Aug 8, 2020',
#   'Aug 8, 2020',
#   'Aug 8, 2020',
#   'Aug 8, 2020',
#   'Aug 8, 2020',
#   'Aug 10, 2020',
#   'Aug 10, 2020',
#   'Aug 10, 2020',
#   'Aug 10, 2020',
#   'Aug 12, 2020',
#   'Aug 12, 2020',
#   'Aug 12, 2020',
#   'Aug 12, 2020',
#   'Aug 12, 2020',
#   'Aug 12, 2020',
#   'Aug 12, 2020',
#   'Aug 12, 2020',
#   'Aug 16, 2020',
#   'Aug 16, 2020',
#   'Aug 27, 2020',
#   'Aug 27, 2020',
#   'Sep 2, 2020',
#   'Sep 2, 2020',
#   'Oct 28, 2018'],
#  'name': ['Corey Anderson',
#   'Corey Anderson',
#   'Corey Anderson',
#   'Ray Borg',
#   'Ray Borg',
#   'Roman Bogatov',
#   'Roman Bogatov',
#   'Tai Tuivasa',
#   'Tai Tuivasa',
#   'Paige VanZant',
#   'Paige VanZant',
#   'Bethe Correia',
#   'Bethe Correia',
#   'Evan Dunham',
#   'Evan Dunham',
#   'Max Rohskopf',
#   'Max Rohskopf',
#   'Daniel Cormier *',
#   'Daniel Cormier *',
#   'Kevin Croom',
#   'Kevin Croom',
#   'Ricardo Lamas *',
#   'Ricardo Lamas *',
#   'Sergio Giglio'],
# ...

# %%
import pandas as pd

# %%
new_data = pd.DataFrame(data,columns=["date","name","nickname","division","endeavor_record","mma_record"])

# %%
new_data
# Out:
#             date              name                    nickname  \
# 0    Aug 8, 2020    Corey Anderson                    Overtime
# 1    Aug 8, 2020    Corey Anderson                    Overtime
# 2    Aug 8, 2020    Corey Anderson                    Overtime
# 3    Aug 8, 2020          Ray Borg        The Tazmexican Devil
# 4    Aug 8, 2020          Ray Borg        The Tazmexican Devil
# 5   Aug 10, 2020     Roman Bogatov
# 6   Aug 10, 2020     Roman Bogatov
# 7   Aug 10, 2020       Tai Tuivasa                     Bam Bam
# 8   Aug 10, 2020       Tai Tuivasa                     Bam Bam
# 9   Aug 12, 2020     Paige VanZant                    12 Gauge
# 10  Aug 12, 2020     Paige VanZant                    12 Gauge
# 11  Aug 12, 2020     Bethe Correia                     Pitbull
# 12  Aug 12, 2020     Bethe Correia                     Pitbull
# 13  Aug 12, 2020       Evan Dunham
# 14  Aug 12, 2020       Evan Dunham
# 15  Aug 12, 2020      Max Rohskopf
# ...

# %%
new_data["nickname"].dtype
# Out:
# dtype('O')

# %%
new_data["nickname"] = new_data["nickname"].replace('',"nan")

# %%
new_data
# Out:
#             date              name                    nickname  \
# 0    Aug 8, 2020    Corey Anderson                    Overtime
# 1    Aug 8, 2020    Corey Anderson                    Overtime
# 2    Aug 8, 2020    Corey Anderson                    Overtime
# 3    Aug 8, 2020          Ray Borg        The Tazmexican Devil
# 4    Aug 8, 2020          Ray Borg        The Tazmexican Devil
# 5   Aug 10, 2020     Roman Bogatov                         nan
# 6   Aug 10, 2020     Roman Bogatov                         nan
# 7   Aug 10, 2020       Tai Tuivasa                     Bam Bam
# 8   Aug 10, 2020       Tai Tuivasa                     Bam Bam
# 9   Aug 12, 2020     Paige VanZant                    12 Gauge
# 10  Aug 12, 2020     Paige VanZant                    12 Gauge
# 11  Aug 12, 2020     Bethe Correia                     Pitbull
# 12  Aug 12, 2020     Bethe Correia                     Pitbull
# 13  Aug 12, 2020       Evan Dunham                         nan
# ...

# %%
new_data["name"].unique
# Out:
# <bound method Series.unique of 0       Corey Anderson
# 1       Corey Anderson
# 2       Corey Anderson
# 3             Ray Borg
# 4             Ray Borg
# 5        Roman Bogatov
# 6        Roman Bogatov
# 7          Tai Tuivasa
# 8          Tai Tuivasa
# 9        Paige VanZant
# 10       Paige VanZant
# 11       Bethe Correia
# 12       Bethe Correia
# 13         Evan Dunham
# 14         Evan Dunham
# 15        Max Rohskopf
# 16        Max Rohskopf
# 17    Daniel Cormier *
# 18    Daniel Cormier *
# 19         Kevin Croom
# 20         Kevin Croom
# 21     Ricardo Lamas *
# 22     Ricardo Lamas *
# 23       Sergio Giglio
# Name: name, dtype: object>

# %%
new_data.drop_duplicates(subset="name",keep="first",inplace=True)

# %%
new_data = new_data.iloc[0:11]

# %%
new_data.to_csv("ufc_fighter.csv",index=None)

# %%
new_data.dtypes
# Out:
# date               object
# name               object
# nickname           object
# division           object
# endeavor_record    object
# mma_record         object
# dtype: object

# %%
clean_data = pd.read_csv("ufc_fighter.csv")

# %%
clean_data
# Out:
#             date              name                    nickname  \
# 0    Aug 8, 2020    Corey Anderson                    Overtime
# 1    Aug 8, 2020          Ray Borg        The Tazmexican Devil
# 2   Aug 10, 2020     Roman Bogatov                         NaN
# 3   Aug 10, 2020       Tai Tuivasa                     Bam Bam
# 4   Aug 12, 2020     Paige VanZant                    12 Gauge
# 5   Aug 12, 2020     Bethe Correia                     Pitbull
# 6   Aug 12, 2020       Evan Dunham                         NaN
# 7   Aug 12, 2020      Max Rohskopf                         NaN
# 8   Aug 16, 2020  Daniel Cormier *                          DC
# 9   Aug 27, 2020       Kevin Croom  The Hard Hitting Hillbilly
# 10   Sep 2, 2020   Ricardo Lamas *                   The Bully
#
#                 division        endeavor_record             mma_record
# 0      Light Heavyweight               ['10–5']               ['13–5']
# ...

# %%
clean_data["date"] = pd.to_datetime(clean_data["date"],infer_datetime_format=True)

# %%
clean_data
# Out:
#          date              name                    nickname  \
# 0  2020-08-08    Corey Anderson                    Overtime
# 1  2020-08-08          Ray Borg        The Tazmexican Devil
# 2  2020-08-10     Roman Bogatov                         NaN
# 3  2020-08-10       Tai Tuivasa                     Bam Bam
# 4  2020-08-12     Paige VanZant                    12 Gauge
# 5  2020-08-12     Bethe Correia                     Pitbull
# 6  2020-08-12       Evan Dunham                         NaN
# 7  2020-08-12      Max Rohskopf                         NaN
# 8  2020-08-16  Daniel Cormier *                          DC
# 9  2020-08-27       Kevin Croom  The Hard Hitting Hillbilly
# 10 2020-09-02   Ricardo Lamas *                   The Bully
#
#                 division        endeavor_record             mma_record
# 0      Light Heavyweight               ['10–5']               ['13–5']
# 1           Bantamweight                ['7–5']               ['13–5']
# ...

# %%
clean_data.dtypes
# Out:
# date               datetime64[ns]
# name                       object
# nickname                   object
# division                   object
# endeavor_record            object
# mma_record                 object
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(clean_data["date"])
plt.show()
# Out:
# C:\Users\raada\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
